# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %time sum(range(100))
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 11 µs
# 4950

# %%
# %timeit sum(range(100))
# Out:
# 2.36 µs ± 111 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# импортируем необходимые библиотеки
import numpy as np

# создаем массивы значений
x = np.random.randn(10000000)
y = np.random.randn(10000000)

# %%
# %%time

nx = len(x)
result = 0.0
count = 0
for i in range(nx):
    result += x[i] - y[i]
    count += 1
result / count
# Out:
# CPU times: user 6.05 s, sys: 2.46 ms, total: 6.06 s
# Wall time: 6.06 s
# np.float64(0.0001057958199627566)

# %%
# %%timeit

nx = len(x)
result = 0.0
count = 0
for i in range(nx):
    result += x[i] - y[i]
    count += 1
result / count
# Out:
# 4.39 s ± 612 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# импортируем необходимые библиотеки
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import urllib.request
urllib.request.urlretrieve(
    "https://github.com/Gewissta/Data_Preprocessing_in_Python/blob/main/code/Data/Visualizations.csv?raw=true",
    "Visualizations.csv"
)

data = pd.read_csv('Visualizations.csv', encoding='cp1251', sep=';')
data.head()
# Out:
#    возраст          образование  стаж  проживание  доход      статус дефолт
# 0       41        незак. высшее    17          12    176  постоянный     да
# 1       27     неполное среднее    10           6     31  постоянный    нет
# 2       40              среднее    15          14     55  постоянный    нет
# 3       41              среднее    15          14    120  постоянный    нет
# 4       24  среднее специальное     2           0     28  постоянный     да

# %%
# строим состыкованную столбиковую диаграмму
pd.crosstab(data['образование'], data['дефолт']).plot.barh(stacked=True);
